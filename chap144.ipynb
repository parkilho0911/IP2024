# %% [markdown]
# ##### Smoothing Images

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
from cv2 import GaussianBlur, bilateralFilter, medianBlur
img = cv2.imread('hero.jpg')
kernel = np.ones((5,5),np.float32)/25
dst = cv2.filter2D(img,-1,kernel)
blur5 = cv2.GaussianBlur(img,(15,15),0)
# blur = cv2.GaussianBlur(img,(5,5),0)
# blur = cv2.GaussianBlur(img,(5,5),0)
GaussianBlur5 = cv2.GaussianBlur(img,(5,5),0)
medianBlur5 = cv2.medianBlur(img,15)
bilateralFilter5 = cv2.bilateralFilter(img,9,75,75)
plt.subplot(121),plt.imshow(img),plt.title('blur5')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(dst),plt.title('GaussianBlur')
plt.xticks([]), plt.yticks([])
plt.show()
